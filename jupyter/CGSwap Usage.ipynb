# %%
dppc.mcs(cdl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a5f2183e221a> in <module>()
# ----> 1 dppc.mcs(cdl)
#
# /sansom/n15/shil3498/dphil/prj/2016-01-06_Phospholipids/phosynth/jupyter/cgswap/residue_parameters.py in mcs(self, other, threshold)
#     104                     candidate_map = {from_atom_id:to_atom_id}
#     105                     connected_similarity = 0
# --> 106                     # Sum up compatible connected nodes
#     107                     for fc_type, tc_type in product(from_connected_types, to_connected_types):
#     108                         similarity = martini_type_similarity(fc_type, tc_type)
#
# NameError: global name 'product' is not defined

# %%
import MDAnalysis as mda

# %%
d = mda.Universe("data/CDL0.gro")

# %%
z = d.select_atoms("all")[0]

# %%
z.position
# Out:
# array([ 38.38000107,  53.59000397,  88.45000458], dtype=float32)
